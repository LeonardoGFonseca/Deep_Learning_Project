# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scikit-learn matplotlib seaborn
# !pip install torch
# !pip install causal_conv1d==1.1.1
# !pip install mamba-ssm==1.2.0.post1
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# ...

# %%
import os
os.chdir('/content')
# !git clone https://github.com/martinzx13/Squiggles-OxfordNanopore-Data-workflow.git
# Out:
# Cloning into 'Squiggles-OxfordNanopore-Data-workflow'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 172 (delta 50), reused 152 (delta 34), pack-reused 0 (from 0)
# Receiving objects: 100% (172/172), 98.35 KiB | 1.40 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !cp "/content/drive/MyDrive/amr_features.h5" \
   /content/Squiggles-OxfordNanopore-Data-workflow/data/processed/hd5f/

# %%
# !python src/training/sweep.py --model_type mamba \
  --h5_path data/processed/hd5f/amr_features.h5 --output_dir pipeline_logs/mamba_sweep
# Out:
# Device: cpu
# Model: mamba, Epochs: 50, Batch: 32, LR: 0.0003
# Fold: KP866
# Mamba unavailable — falling back to GRU
# Failed to connect to the remote Jupyter Server 'https://8080-m-s-kkb-usw4a2-1u712xyfkozhf-a.us-west4-2.prod.colab.dev/'. Verify the server is running and reachable.

# %%
os.chdir('/content/Squiggles-OxfordNanopore-Data-workflow')
# !python src/training/sweep.py --model_type gap \
  --h5_path data/processed/hd5f/amr_features.h5 --output_dir pipeline_logs/gap_sweep
